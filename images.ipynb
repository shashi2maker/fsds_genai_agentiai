# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
from PIL import Image # python imageing library

# %%
img=Image.open(r'C:\Users\shash\Downloads\kalki.jpg')

# %%
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=736x1308>

# %%
img=Image.open(r'C:\Users\shash\Downloads\Thor.jpg')

# %%
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=298x333>

# %%
type(img)
# Out:
# PIL.JpegImagePlugin.JpegImageFile

# %%
numpy.ndarray
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 numpy.ndarray
#
# NameError: name 'numpy' is not defined

# %%
img_arr.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 img_arr.shape
#
# NameError: name 'img_arr' is not defined

# %%
plt.imshow(img_arr)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 plt.imshow(img_arr)
#
# NameError: name 'img_arr' is not defined

# %%
img_red=img_arr.copy()

# %%
img_red

# %%
img_arr==img_red

# %%
plt.imshow(img_red)

# %%
img_red.shape

# %%
plt.imshow(img_red[:,:,0])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 plt.imshow(img_red[:,:,0])
#
# NameError: name 'img_red' is not defined

# %%
img_red[:,:,0]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 img_red[:,:,0]
#
# NameError: name 'img_red' is not defined

# %%
plt.imshow(img_red[:,:,0],cmap='gray')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 plt.imshow(img_red[:,:,0],cmap='gray')
#
# NameError: name 'img_red' is not defined

# %%
plt.imshow(img_red[:,:,0],cmap='Blues')

# %%
plt.imshow(img_red[:,:,0],cmap='PuBu')

# %%
plt.imshow(img_red[:,:,0],cmap='Oranges')

# %%
plt.imshow(img_red[:,:,0],cmap='cividis')

# %%
plt.imshow(img_red[:,:,0],cmap='plasma')

# %%
img1=Image.open(r'C:\Users\shash\Downloads\kalki.jpg')

# %%
img1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 img1
#
# NameError: name 'img1' is not defined

# %%
type(img)

# %%
imgarr.shape

# %%
img_red

# %%
plt.imshow(img1_arr)

# %%
img

# %%
plt.imshow(img1_arr)

# %%
img1_arr.shape

# %%
img1

# %%
karna_img=Image.open(r'C:\Users\shash\Downloads\karna.jpg')

# %%
karna_img=Image.open(r'C:\Users\shash\Downloads\karna.jpg')

# %%
img1=Image.open(r'C:\Users\shash\Downloads\kalki.jpg')
